# %%
import pandas as pd

# %%
data = pd.read_csv('datasets/san_fran_biz.csv')

# %%
data
# Out:
#            Location_ID  Business_Account_Number  \
# 0       0000024-02-999                       24
# 1       0000028-02-001                       28
# 2       0000052-01-001                       52
# 3       0000071-01-001                       71
# 4       0000071-02-001                       71
# 5       0000071-02-003                       71
# 6       0000071-03-001                       71
# 7       0000086-01-001                       86
# 8       0000086-02-002                       86
# 9       0000188-01-001                      188
# 10      0000189-02-001                      189
# 11      0000189-03-001                      189
# 12      0000205-01-001                      205
# 13      0000216-01-001                      216
# 14      0000216-02-001                      216
# 15      0000224-01-001                      224
# 16      0000244-01-001                      244
# 17      0000244-02-001                      244
# ...

# %%
grouped = data['City'].groupby(data['Zip_Code'])

# %%
grouped = grouped.count().sort_values()

# %%
grouped.to_csv('bizperzip.csv')
